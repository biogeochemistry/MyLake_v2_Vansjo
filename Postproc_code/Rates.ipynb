# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as tkr
import matplotlib.dates as mdates
import datetime
from matplotlib.colors import ListedColormap
import seaborn as sns
sns.set_style("whitegrid")
sns.set_style("ticks")
import scipy.io as sio
import cmocean
from ploting import *

# %matplotlib inline

from datetime import datetime
str(datetime.now())
# Out:
# '2017-07-31 09:49:14.344304'

# %%
from ploting import *
plotter = ResultsPlotter(years_ago=0.0)

# %%
plotter.flux('FeOH3', convert_units=1)

# %%
plotter.rate_profile('sediment', ['R3'])
# Out:
# /Users/MarkelovIgor/git/biogeochemistry/MyLake_v2_Vansjo/Postproc_code/ploting.py:204: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = results['rates'][0, 0][e][0, 0][:, -1 + end]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-3a89fc8c9f49> in <module>()
# ----> 1 plotter.rate_profile('sediment', ['R3'])
#
# /Users/MarkelovIgor/git/biogeochemistry/MyLake_v2_Vansjo/Postproc_code/ploting.py in rate_profile(self, env, elem, years_ago)
#     202         lines = {}
#     203         for e in elem:
# --> 204             y = results['rates'][0, 0][e][0, 0][:, -1 + end]
#     205             lines[e], = plt.plot(y, -z, lw=3, label=e)
#     206             if env == 'water-column':
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
plotter.rate_profile('sediment', ['R2'])

# %%
plotter.flux('Fe2', convert_units=1)

# %%
plotter.rate_profile('sediment', ['R8'], years_ago=0.0)

# %%
plotter.rate_profile('water-column', ['R16a'])

# %%
plotter.profile('sediment', ['Fe2'], convert_units=False)

# %%
plotter.profile('sediment', ['Fe2'], convert_units=False)

# %%
plotter.flux('Fe2', convert_units=True)

# %%
plotter.contour_plot('water-column', ['Fe3'])

# %%
plotter.bulk_sediment_profile(['O2',], years_ago=0.3)

# %%
plotter.profile('sediment', ['O2',])

# %%
plotter.profile('sediment', ['OM1', 'OM2'])

# %%
plotter.profile('water-column', ['Chl'])

# %%
a = 2
