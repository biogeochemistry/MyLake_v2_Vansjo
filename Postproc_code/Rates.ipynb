# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as tkr
import matplotlib.dates as mdates
import datetime
from matplotlib.colors import ListedColormap
import seaborn as sns
sns.set_style("whitegrid")
sns.set_style("ticks")
import scipy.io as sio
import cmocean
from ploting import *

# %matplotlib inline

from datetime import datetime
str(datetime.now())
# Out:
# '2017-08-26 13:40:23.114164'

# %%
from ploting import *
plotter = ResultsPlotter(f='../IO/test_1.mat')

# %%
plotter.flux('FeOH3', convert_units=1)

# %%
plotter.rate_profile('sediment', ['R3a'])

# %%
plotter.rate_profile('sediment', ['R1a'])

# %%
plotter.flux('Fe2', convert_units=1)

# %%
plotter.rate_profile('sediment', ['R13'], years_ago=0.0)

# %%
plotter.rate_profile('sediment', ['R23'])

# %%
plotter.profile('sediment', ['Fe2'], convert_units=False)

# %%
plotter.profile('sediment', ['Fe2'], convert_units=False)

# %%
plotter.flux('Fe2', convert_units=True)

# %%
plotter.contour_plot('water', ['Fe3'])

# %%
plotter.bulk_sediment_profile(['O2',], years_ago=0.3)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-37-e7c6da9794e3> in <module>()
# ----> 1 plotter.bulk_sediment_profile(['O2',], years_ago=0.3)
#
# ~/git/biogeochemistry/MyLake_v2_Vansjo/Postproc_code/ploting.py in bulk_sediment_profile(self, elem, convert_units, years_ago, cmap)
#     398             coef, units = self.unit_converter(convert_units, 'sediment', e)
#     399             if e in disolved:
# --> 400                 y = results['concentrations'][0, 0][e][0, 0][:, -1 + end] * coef * fi
#     401             elif e in solid:
#     402                 y = results['concentrations'][0, 0][e][0, 0][:, -1 + end] * coef * (1 - fi)
#
# IndexError: index -111 is out of bounds for axis 1 with size 31

# %%
plotter.profile('sediment', ['O2',])

# %%
plotter.profile('sediment', ['POC', 'POP'])

# %%
plotter.profile('water', ['Chl'])
