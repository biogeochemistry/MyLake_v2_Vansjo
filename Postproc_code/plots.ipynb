# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as tkr
import matplotlib.dates as mdates
import datetime
from matplotlib.colors import ListedColormap
import seaborn as sns
sns.set_style("whitegrid")
sns.set_style("ticks")
import scipy.io as sio
import cmocean
from ploting import *

# %matplotlib inline

from datetime import datetime
str(datetime.now())
# Out:
# '2017-08-18 15:42:05.130902'

# %%
from ploting import *
plotter = ResultsPlotter(f='../IO/MyLakeResults_2.mat')

# %%
plotter.profile('sediment', ['CO2'], log_scale=0)

# %%
plotter.profile('sediment', ['pH'], log_scale=0)

# %%
plotter.profile('sediment', ['FeOH3','FeOOH'], log_scale=1)

# %%
plotter.bulk_sediment_profile(['PO4adsa', 'PO4adsb'])

# %%
plotter.profile('sediment', ['CO2'], convert_units=0, years_ago=0,)

# %%
plotter.flux('POP', convert_units=1, years_ago=0, smoothing_factor=0)

# %%
plotter.flux('CO2', convert_units=1, years_ago=0, smoothing_factor=0)

# %%
plotter.flux('HCO3', convert_units=1, years_ago=0, smoothing_factor=0)

# %%
plotter.flux('PO4', convert_units=1, years_ago=0, smoothing_factor=0)

# %%
plotter.flux('POP', convert_units=1, smoothing_factor=0)

# %%
plotter.profile('water-column', ['CO2aq'], years_ago=0, convert_units=1)

# %%
plotter.profile('sediment', ['HCO3'], years_ago=0, convert_units=0)

# %%
plotter.profile('sediment', ['POC'])

# %%
plotter.profile('sediment', ['POP'], years_ago=0)

# %%
plotter.profile('sediment', ['PO4','PO4adsa', 'PO4adsb'], years_ago=0)

# %%
plotter.contour_plot('water-column', ['CH4g'], years_ago=0, convert_units=1)

# %%
plotter.profile('water-column', ['CH4g'], years_ago=0, convert_units=1)

# %%
plotter.flux('CH4g', convert_units=1, smoothing_factor=0)

# %%
plotter.profile('sediment', ['CH4g'], years_ago=0., convert_units=0)

# %%
plotter.contour_plot('water-column', ['O2'],  cmap=cmocean.cm.oxy, years_ago=0)

# %%
plotter.contour_plot('sediment', ['O2'],  cmap=cmocean.cm.oxy)

# %%
plotter.profile('sediment', ['Fe2'], years_ago=0.)

# %%
plotter.profile('sediment', ['O2','Fe2', 'HS', 'FeS2'], years_ago=0.)

# %%
plotter.profile('sediment', ['O2','Fe2', 'SO4', 'HS', 'CH4aq', 'CH4g'], years_ago=0.)

# %%
plotter.profile('water-column', ['Fe3'])

# %%
plotter.contour_plot('water-column', ['Chl'],  cmap=cmocean.cm.algae)

# %%
plotter.contour_plot('water-column', ['C'],  cmap=cmocean.cm.algae)

# %%
plotter.profile('sediment', ['PO4adsa'])

# %%
plotter.profile('sediment', ['POC'])

# %%
plotter.bulk_sediment_profile(['PO4', 'PO4adsa', 'PO4adsb'])

# %%
plotter.profile('sediment', ['H'])

# %%
plotter.profile('sediment', ['SO4', 'HS', 'Fe2', 'FeS', 'FeS2'], years_ago=0.)

# %%
plotter.profile('sediment', ['POP', 'DOP', 'POC', 'DOC'])

# %%
plotter.contour_plot('water-column', ['DOP', 'Chl', 'C', 'P', 'PP'])

# %%
plotter.flux('O2',convert_units=1, smoothing_factor=0)

# %%
plotter.flux('POC', convert_units=1, smoothing_factor=0)

# %%
plotter.flux('FeOH3', convert_units=1)

# %%
plotter.flux('NO3')

# %%
plotter.contour_plot('water-column', ['POC'], convert_units=0)

# %%
plotter.contour_plot('water-column', ['PP'])

# %%
plotter.contour_plot('water-column', ['H_sw'],  cmap=cmocean.cm.solar)

# %%
plotter.contour_plot('water-column', ['H_sw_2'],  cmap=cmocean.cm.solar)

# %%
plotter.contour_plot('sediment', ['DOP'])

# %%
plotter.profile('sediment', ['NO3', 'NH4'])

# %%
plotter.flux('O2', convert_units=1)

# %%
plotter.contour_plot('water-column', ['T'],  cmap=cmocean.cm.thermal)

# %%
plotter.contour_plot('water-column', ['NH4'])

# %%
plotter.contour_plot('water-column', ['NO3'], convert_units=False)

# %%
plotter.profile('water-column', ['O2'], convert_units=True)

# %%
plotter.profile('sediment', ['O2'], convert_units=False, years_ago=0.)

# %%
plotter.profile('water-column', ['P'], convert_units=False)

# %%
plotter.profile('sediment', ['PO4', 'PO4adsa', 'PO4adsb'], convert_units=0)

# %%
plotter.flux('POP', convert_units=1)

# %%
plotter.profile('sediment', ['O2'], convert_units=False)

# %%
plotter.contour_plot('water-column', ['NO3'], convert_units=1)

# %%
plotter.contour_plot('sediment', ['NO3'])

# %%
plotter.contour_plot('water-column', ['Fe3'], convert_units=0, years_ago=0)

# %%
plotter.flux('NH4', convert_units=1)

# %%
plotter.flux('NO3', convert_units=1)

# %%
plotter.flux('POP', convert_units=1)

# %%
plotter.flux('Chl', convert_units=1)

# %%
plotter.contour_plot('sediment', ['PO4'], convert_units=0)
