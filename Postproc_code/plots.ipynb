# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as tkr
import matplotlib.dates as mdates
import datetime
from matplotlib.colors import ListedColormap
import seaborn as sns
sns.set_style("whitegrid")
sns.set_style("ticks")
import scipy.io as sio
import cmocean
from ploting import *

# %matplotlib inline

from datetime import datetime
str(datetime.now())
# Out:
# '2017-05-17 07:57:13.486251'

# %%
from ploting import *
plotter = ResultsPlotter()

# %%
plotter.bulk_sediment_profile(['PO4'])

# %%
plotter.flux('PO4', convert_units=0)

# %%
plotter.flux('NO3')

# %%
plotter.contour_plot('water-column', ['O2zt'],  cmap=cmocean.cm.oxy)

# %%
plotter.contour_plot('sediment', ['O2zt'],  cmap=cmocean.cm.oxy)

# %%
plotter.contour_plot('water-column', ['Fe3zt'])

# %%
plotter.contour_plot('water-column', ['Chlzt'],  cmap=cmocean.cm.algae)

# %%
plotter.contour_plot('water-column', ['Czt'],  cmap=cmocean.cm.algae)

# %%
plotter.profile('sediment', ['FeOH3zt', 'Fe2zt', 'FeSzt'])

# %%
plotter.profile('sediment', ['O2zt','NO3zt', 'SO4zt'], years_ago=0.1)

# %%
plotter.bulk_sediment_profile(['PO4zt'])

# %%
plotter.profile('sediment', ['SO4zt', 'HSzt'])

# %%
plotter.profile('sediment', ['OMbzt', 'OMzt', 'DOM2zt'])

# %%
plotter.contour_plot('water-column', ['DOPzt', 'Chlzt', 'Czt', 'Pzt', 'PPzt'])

# %%
plotter.flux('O2',convert_units=1, smoothing_factor=1)

# %%
plotter.flux('OM2', convert_units=1)

# %%
plotter.flux('OM1')

# %%
plotter.flux('Fe2', convert_units=1)

# %%
plotter.flux('NO3')

# %%
plotter.flux('FeOH3', convert_units=1)

# %%
plotter.contour_plot('water-column', ['POCzt'])

# %%
plotter.contour_plot('water-column', ['PPzt'])

# %%
plotter.contour_plot('water-column', ['H_sw_zt'],  cmap=cmocean.cm.solar)

# %%
plotter.contour_plot('water-column', ['H_sw_zt_2'],  cmap=cmocean.cm.solar)

# %%
plotter.contour_plot('sediment', ['DOM1zt'])

# %%
plotter.profile('sediment', ['NO3zt', 'NH4zt'])

# %%
plotter.flux('O2')

# %%
plotter.contour_plot('water-column', ['Tzt'],  cmap=cmocean.cm.thermal)

# %%
plotter.contour_plot('water-column', ['NH4zt'])

# %%
plotter.contour_plot('water-column', ['NO3zt'], convert_units=False)

# %%
plotter.profile('water-column', ['O2zt'], convert_units=True)

# %%
plotter.profile('sediment', ['O2zt'], convert_units=False, years_ago=0.4)

# %%
plotter.profile('water-column', ['Pzt'], convert_units=False)

# %%
plotter.profile('sediment', ['PO4zt'], convert_units=False)

# %%
plotter.flux('O2')

# %%
plotter.profile('sediment', ['O2zt'], convert_units=False)

# %%
plotter.contour_plot('water-column', ['NO3zt'], convert_units=True)

# %%
plotter.contour_plot('sediment', ['NH4zt'])

# %%
plotter.contour_plot('sediment', ['PO4zt'])
