# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as tkr
import matplotlib.dates as mdates
import datetime
from matplotlib.colors import ListedColormap
import seaborn as sns
sns.set_palette(sns.color_palette("deep", 10))
sns.set_style("whitegrid")
sns.set_style("ticks")
import scipy.io as sio
import cmocean
from ploting import *

# %matplotlib inline

from datetime import datetime
str(datetime.now())
# Out:
# /Users/imarkelo/anaconda3/lib/python3.6/site-packages/cmocean/tools.py:76: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not mpl.cbook.is_string_like(rgbin[0]):
# '2019-08-03 18:39:33.241265'

# %%
# plotter = ResultsPlotter(f='/Volumes/Igor EcoHDD/Scenarios/final_fit_192.mat')
plotter = ResultsPlotter(f='/Users/imarkelo/git/MyLake_v2_Vansjo/IO/sediment_pH_enabled.mat')

# %%
plotter.flux('PO4', convert_units=1, years_ago=0, smoothing_factor=0)
# Out:
# /Users/imarkelo/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /Users/imarkelo/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /Users/imarkelo/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /Users/imarkelo/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plotter.flux('Fe2', convert_units=1, years_ago=0, smoothing_factor=0)

# %%
plotter.contour_plot('sediment', ['pH'], years_ago=0.)

# %%
plotter.profile('sediment', ['pH'], log_scale=0, years_ago=0.1)

# %%
plotter.contour_plot('sediment', ['pH'], years_ago=0.)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a50a8fa91416> in <module>
# ----> 1 plotter.contour_plot('sediment', ['pH'], years_ago=0.)
#
# NameError: name 'plotter' is not defined

# %%
plotter.flux('PO4', convert_units=1, years_ago=1, smoothing_factor=0)

# %%
plotter.profile('sediment', ['POC'], log_scale=0, years_ago=0)

# %%
plotter.profile('sediment', ['FeOH3',], log_scale=0)

# %%
plotter.profile('sediment', ['Ca3PO42', 'PO4adsb', 'PO4', 'Fe3PO42'], log_scale=0)

# %%
plotter.profile('sediment', ['pH'], years_ago=0.5)

# %%
plotter.profile('sediment', ['POC'], log_scale=0,years_ago=10)

# %%
plotter.profile('sediment', ['PO4','PO4adsa', 'PO4adsb'])

# %%
plotter.flux('POP', convert_units=1, years_ago=0, smoothing_factor=0)

# %%
plotter.flux('PO4', convert_units=1, years_ago=0, smoothing_factor=0)

# %%
plotter.flux('Fe2', convert_units=1, years_ago=0, smoothing_factor=0)

# %%
plotter.flux('FeOH3', convert_units=1, years_ago=0, smoothing_factor=0)

# %%
plotter.flux('CH4g', convert_units=1, smoothing_factor=0)

# %%
plotter.flux('HCO3', convert_units=1, smoothing_factor=0)

# %%
plotter.profile('sediment', ['FeOH3','FeOOH', 'PO4adsa', 'PO4adsb'], years_ago=0, convert_units=0)

# %%
plotter.bulk_sediment_profile(['PO4adsa', 'PO4adsb', 'Ca3PO42', 'Fe3PO42'], years_ago=0)

# %%
plotter.contour_plot('water', ['P'], years_ago=0, convert_units=1)
# Out:
# /Users/imarkelo/git/MyLake_v2_Vansjo/Postproc_code/ploting.py:507: RuntimeWarning: invalid value encountered in greater
#   -TCz * (TCz > 1),

# %%
plotter.profile('sediment', ['CaCO3'], years_ago=0, convert_units=0)

# %%
plotter.flux('POC', convert_units=1, smoothing_factor=0)

# %%
plotter.flux('O2', convert_units=1, smoothing_factor=0)

# %%
plotter.profile('sediment', ['CH4g'], years_ago=0., convert_units=0)

# %%
plotter.contour_plot('water', ['POC'], years_ago=0)

# %%
plotter.contour_plot('water', ['O2'],  cmap=cmocean.cm.oxy, years_ago=0)

# %%
plotter.contour_plot('sediment', ['O2'],  cmap=cmocean.cm.oxy)

# %%
plotter.profile('sediment', ['Fe2'], years_ago=0.)

# %%
plotter.bulk_sediment_profile(['FeS', 'FeS2'], years_ago=0.)

# %%
plotter.profile('sediment', ['O2',], years_ago=0.4)

# %%
plotter.contour_plot('water', ['P',], years_ago=45)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-6881d934695b> in <module>()
# ----> 1 plotter.contour_plot('water', ['P',], years_ago=45)
#
# ~/git/MyLake_v2_Vansjo/Postproc_code/ploting.py in contour_plot(self, env, elem, convert_units, years_ago, cmap)
#     485                 z += results[e][0, 0][0:-1, start:end] * coef
#     486
# --> 487         v = np.linspace(0, z.max(), 51, endpoint=True)
#     488         CS = plt.contourf(
#     489             X, Y, z, v, cmap=cmap, origin='lower', vmin=0,
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py in _amax(a, axis, out, keepdims)
#      24 # small reductions
#      25 def _amax(a, axis=None, out=None, keepdims=False):
# ---> 26     return umr_maximum(a, axis, None, out, keepdims)
#      27
#      28 def _amin(a, axis=None, out=None, keepdims=False):
#
# ...

# %%
plotter.profile('sediment', ['SO4',], years_ago=0.5, convert_units=1)

# %%
plotter.profile('water', ['Fe3'], years_ago=0)

# %%
plotter.contour_plot('water', ['P'], years_ago=0)

# %%
plotter.flux('PO4', convert_units=1)

# %%
plotter.contour_plot('sediment', ['PO4'], years_ago=0)

# %%
plotter.profile('sediment', ['POC'])

# %%
plotter.flux('PO4', convert_units=1, years_ago=0)

# %%
plotter.profile('sediment', ['H3O'])

# %%
plotter.bulk_sediment_profile(['O2','NO3','Fe2','SO4','CH4aq','FeS', 'FeS2'], years_ago=0.4)

# %%
plotter.profile('sediment', ['O2','NO3','Fe2','SO4','CH4aq','FeS', 'FeS2'], years_ago=0.4)

# %%
plotter.profile('sediment', ['POP', 'DOP', 'POC', 'DOC'], log_scale=1)

# %%
plotter.contour_plot('water', ['DOP', 'Chl', 'C', 'P', 'PP'])

# %%
plotter.flux('O2',convert_units=1, smoothing_factor=0, years_ago=0)

# %%
plotter.flux('POC', convert_units=1, smoothing_factor=0)

# %%
plotter.flux('FeOH3', convert_units=1)

# %%
plotter.flux('Fe2', convert_units=1)

# %%
plotter.contour_plot('water', ['POC'], convert_units=0)

# %%
plotter.contour_plot('water', ['Ca2'])

# %%
plotter.contour_plot('water', ['H_sw'],  cmap=cmocean.cm.solar)

# %%
plotter.contour_plot('water', ['H_sw_2'],  cmap=cmocean.cm.solar)

# %%
plotter.contour_plot('sediment', ['DOP'])

# %%
plotter.profile('sediment', ['NO3', 'NH4'])

# %%
plotter.flux('O2', convert_units=1)

# %%
plotter.contour_plot('water', ['T'],  cmap=cmocean.cm.thermal)

# %%
plotter.contour_plot('water', ['NH4'])

# %%
plotter.contour_plot('water', ['P'], convert_units=False)

# %%
plotter.profile('water', ['O2'], convert_units=True)

# %%
plotter.profile('sediment', ['O2'], convert_units=False, years_ago=0.)

# %%
plotter.profile('water', ['P'], convert_units=False)

# %%
plotter.profile('sediment', ['PO4', 'PO4adsa', 'PO4adsb'], convert_units=0)

# %%
plotter.flux('PO4', convert_units=1)

# %%
plotter.profile('sediment', ['O2'], convert_units=False)

# %%
plotter.contour_plot('water', ['P'], convert_units=1)

# %%
plotter.contour_plot('sediment', ['NO3'])

# %%
plotter.contour_plot('water', ['Fe3'], convert_units=0, years_ago=0)

# %%
plotter.flux('NH4', convert_units=1)

# %%
plotter.flux('SO4', convert_units=1)

# %%
plotter.flux('POP', convert_units=1)

# %%
plotter.flux('Chl', convert_units=1)

# %%
plotter.contour_plot('sediment', ['Chl'], cmap=cmocean.cm.algae, convert_units=0)

# %%
water = plotter.env_getter('water')

# %%
plt.semilogx(water['params'][0,0]['Az'][0][0], -water['params'][0,0]['zz'][0][0])
plt.hlines(-30, 5e3, 5e5, linestyle='-.', )
plt.vlines(5e5, -41, -30, linestyle='-.', )
plt.ylabel('Depth, m')
plt.xlim(5e3,3e7)
plt.ylim(-41,0)
plt.xlabel('Area, m$^2$')
plt.grid(linestyle='-', linewidth=0.2)

# %%
plt.plot(water['params'][0,0]['Az'][0][0], -water['params'][0,0]['zz'][0][0])
# plt.hlines(-30, 5e3, 5e5, linestyle='-.', )
# plt.vlines(5e5, -41, -30, linestyle='-.', )
plt.ylabel('Depth, m')
# plt.xlim(5e3,3e7)
plt.ylim(-41,0)
plt.xlabel('Area, m$^2$')
plt.grid(linestyle='-', linewidth=0.2)
