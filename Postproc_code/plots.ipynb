# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as tkr
import matplotlib.dates as mdates
import datetime
from matplotlib.colors import ListedColormap
import seaborn as sns
sns.set_style("whitegrid")
sns.set_style("ticks")
import scipy.io as sio
import cmocean
from ploting import *

# %matplotlib inline

from datetime import datetime
str(datetime.now())
# Out:
# '2017-05-24 14:38:41.488079'

# %%
from ploting import *
plotter = ResultsPlotter()

# %%
plotter.bulk_sediment_profile(['PO4'])

# %%
plotter.flux('PO4', convert_units=1)

# %%
plotter.flux('NO3')

# %%
plotter.contour_plot('water-column', ['O2'],  cmap=cmocean.cm.oxy)

# %%
plotter.contour_plot('sediment', ['O2'],  cmap=cmocean.cm.oxy)

# %%
plotter.contour_plot('water-column', ['Fe3'])

# %%
plotter.contour_plot('water-column', ['Chl'],  cmap=cmocean.cm.algae)

# %%
plotter.contour_plot('water-column', ['C'],  cmap=cmocean.cm.algae)

# %%
plotter.profile('sediment', ['FeOH3', 'Fe2', 'FeS'])

# %%
plotter.profile('sediment', ['O2','NO3', 'SO4'], years_ago=0.0)

# %%
plotter.bulk_sediment_profile(['PO4'])

# %%
plotter.profile('sediment', ['SO4', 'HS'])

# %%
plotter.profile('sediment', ['OM2', 'OM1', 'DOM2'])

# %%
plotter.contour_plot('water-column', ['DOP', 'Chl', 'C', 'P', 'PP'])

# %%
plotter.flux('O2',convert_units=1, smoothing_factor=1)

# %%
plotter.flux('OM2', convert_units=1)

# %%
plotter.flux('OM1')

# %%
plotter.flux('Fe2', convert_units=1)

# %%
plotter.flux('NO3')

# %%
plotter.flux('FeOH3', convert_units=1)

# %%
plotter.contour_plot('water-column', ['POC'])

# %%
plotter.contour_plot('water-column', ['PP'])

# %%
plotter.contour_plot('water-column', ['H_sw'],  cmap=cmocean.cm.solar)

# %%
plotter.contour_plot('water-column', ['H_sw_2'],  cmap=cmocean.cm.solar)

# %%
plotter.contour_plot('sediment', ['DOM1'])

# %%
plotter.profile('sediment', ['NO3', 'NH4'])

# %%
plotter.flux('O2')

# %%
plotter.contour_plot('water-column', ['T'],  cmap=cmocean.cm.thermal)

# %%
plotter.contour_plot('water-column', ['NH4'])

# %%
plotter.contour_plot('water-column', ['NO3'], convert_units=False)

# %%
plotter.profile('water-column', ['O2'], convert_units=True)

# %%
plotter.profile('sediment', ['O2'], convert_units=False, years_ago=0.0)

# %%
plotter.profile('water-column', ['P'], convert_units=False)

# %%
plotter.profile('sediment', ['PO4'], convert_units=False)

# %%
plotter.flux('O2')

# %%
plotter.profile('sediment', ['O2'], convert_units=False)

# %%
plotter.contour_plot('water-column', ['NO3'], convert_units=True)

# %%
plotter.contour_plot('sediment', ['NH4'])

# %%
plotter.contour_plot('sediment', ['PO4'])
