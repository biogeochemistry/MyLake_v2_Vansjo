# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as tkr
import matplotlib.dates as mdates
import datetime
from matplotlib.colors import ListedColormap
import seaborn as sns
sns.set_style("whitegrid")
sns.set_style("ticks")
import scipy.io as sio
import cmocean
from ploting import *

# %matplotlib inline

from datetime import datetime
str(datetime.now())
# Out:
# '2017-05-12 11:51:37.425601'

# %%
from ploting import *
plotter = ResultsPlotter(years_ago=0)

# %%
plotter.bulk_sediment_profile(['FeOH3zt'])

# %%
plotter.plot_flux('PO4')

# %%
plotter.plot_flux('NO3')

# %%
plotter.plot_fit()

# %%
plotter.contour_plot('water-column', ['O2zt'],  cmap=cmocean.cm.oxy)

# %%
plotter.contour_plot('sediment', ['O2zt'],  cmap=cmocean.cm.oxy)

# %%
plotter.contour_plot('water-column', ['Fe3zt'])

# %%
plotter.contour_plot('water-column', ['Chlzt'],  cmap=cmocean.cm.algae)

# %%
plotter.contour_plot('water-column', ['Czt'],  cmap=cmocean.cm.algae)

# %%
plotter.plot_profile('sediment', ['FeOH3zt', 'Fe2zt', 'FeSzt'])

# %%
plotter.plot_profile('sediment', ['O2zt','NO3zt', 'SO4zt'])

# %%
plotter.bulk_sediment_profile(['PO4zt'])

# %%
plotter.plot_profile('sediment', ['SO4zt', 'HSzt'])

# %%
plotter.plot_profile('sediment', ['OMbzt', 'OMzt', 'DOM2zt'])

# %%
plotter.contour_plot('water-column', ['DOPzt', 'Chlzt', 'Czt', 'Pzt', 'PPzt'])

# %%
plotter.plot_flux('O2',convert_units=1)

# %%
plotter.plot_flux('OM2')

# %%
plotter.plot_flux('OM1')

# %%
plotter.plot_flux('Fe2', convert_units=1)

# %%
plotter.plot_flux('NO3')

# %%
plotter.plot_flux('FeOH3')

# %%
plotter.contour_plot('water-column', ['POCzt'])

# %%
plotter.contour_plot('water-column', ['PPzt'])

# %%
plotter.contour_plot('water-column', ['H_sw_zt'],  cmap=cmocean.cm.solar)

# %%
plotter.contour_plot('water-column', ['H_sw_zt_2'],  cmap=cmocean.cm.solar)

# %%
plotter.contour_plot('sediment', ['DOM1zt'])

# %%
plotter.plot_profile('sediment', ['NO3zt', 'NH4zt'])

# %%
plotter.plot_flux('O2')

# %%
plotter.contour_plot('water-column', ['Tzt'],  cmap=cmocean.cm.thermal)

# %%
plotter.contour_plot('water-column', ['NH4zt'])

# %%
plotter.contour_plot('water-column', ['NO3zt'], convert_units=False)

# %%
plotter.plot_profile('water-column', ['O2zt'], convert_units=True)

# %%
plotter.plot_profile('sediment', ['O2zt'], convert_units=False)

# %%
plotter.plot_profile('water-column', ['Pzt'], convert_units=False)

# %%
plotter.plot_profile('sediment', ['PO4zt'], convert_units=False)

# %%
plotter.plot_flux('O2')

# %%
plotter.plot_fit()

# %%
plotter.plot_profile('sediment', ['O2zt'], convert_units=False)

# %%
plotter.contour_plot('water-column', ['NO3zt'], convert_units=True)

# %%
plotter.contour_plot('sediment', ['NH4zt'])

# %%
plotter.contour_plot('sediment', ['PO4zt'])

# %%
    mat_contents = sio.loadmat('../IO/MyLakeResults.mat')
    MyLake_results = mat_contents['MyLake_results']
    Sediment_results = mat_contents['Sediment_results']

# %%
np.multiply(Sediment_results['params'][0,0]['fi'][0,0], Sediment_results['FeOH3zt'][0, 0][-1, :])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-907-8b3eb2a16f2d> in <module>()
# ----> 1 np.multiply(Sediment_results['params'][0,0]['fi'][0,0], Sediment_results['FeOH3zt'][0, 0][-1, :])
#
# ValueError: no field of name params

# %%
Sediment_results['params'][0,0]['fi'][0,0][:,-1].shape

# %%
Sediment_results['FeOH3zt'][0, 0][:, -1].shape

# %% [markdown]
# ##
