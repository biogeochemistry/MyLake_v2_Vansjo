# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as tkr
import matplotlib.dates as mdates
import datetime
from matplotlib.colors import ListedColormap
import seaborn as sns
sns.set_style("whitegrid")
sns.set_style("ticks")
import scipy.io as sio

# %matplotlib inline

# %%
from ploting import *

# %%
MyLake_results, Sediment_results = load_data()

# %%
TOTP = np.loadtxt('../obs/store_obs/TOTP.dat', delimiter=',')
Cha_aquaM_march_2017 = np.loadtxt('../obs/store_obs/Cha_aquaM_march_2017.dat', delimiter=',')
PO4 = np.loadtxt('../obs/store_obs/PO4.dat', delimiter=',')
Part = np.loadtxt('../obs/store_obs/Part.dat', delimiter=',')

# %%
plot_fit(MyLake_results)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-aeb91cea8104> in <module>()
# ----> 1 plot_fit(MyLake_results)
#
# /Users/MarkelovIgor/git/biogeochemistry/MyLake_v2_Vansjo/Postproc_code/ploting.py in plot_fit(MyLake_results)
#      73     inx = sum(MyLake_results['z'][0, 0] < 4)[0]
#      74     TOTP = np.sum(MyLake_results['Pzt'][0:inx, :][0]) + np.sum(MyLake_results['PPzt'][0:inx, :][0]) + np.sum(MyLake_results['DOPzt'][0:inx, :][0])
# ---> 75     axes[0].plot(-366 + MyLake_results['days'][0, 0][0], TOTP, c=sns.xkcd_rgb["denim blue"])
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# -> 1892             return func(ax, *args, **kwargs)
# ...

# %%
np.sum(MyLake_results['Pzt'][:8, :]).shape

# %%
plot_profile(Sediment_results, 'O2zt')

# %%
contour_plot(Sediment_results, 'O2zt')

# %%
contour_plot(Sediment_results, 'FeOH3zt')

# %%
contour_plot(Sediment_results, 'PO4adsazt')

# %%
contour_plot(MyLake_results, 'Pzt')

# %%
contour_plot(MyLake_results, 'PPzt')

# %%
contour_plot('PPzt')

# %%
contour_plot('Czt')

# %%
contour_plot('Fe3zt')

# %%
plot_profile('Tzt')
