# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as tkr
import matplotlib.dates as mdates
import datetime
from matplotlib.colors import ListedColormap
import seaborn as sns
sns.set_style("whitegrid")
sns.set_style("ticks")
import scipy.io as sio
import cmocean
from ploting import *

# %matplotlib inline

# %%
MyLake_results, Sediment_results = load_data()

# %%
plot_fit(MyLake_results)

# %%
contour_plot(MyLake_results, 'Tzt', lbl='T, [C]', cmap=cmocean.cm.thermal)

# %%
contour_plot(MyLake_results, 'Tzt', lbl='T, [C]', cmap=cmocean.cm.solar)

# %%
contour_plot(MyLake_results, 'O2zt', lbl=r'Oxygen, $[mg / m^3]$', cmap=cmocean.cm.oxy)

# %%
contour_plot(Sediment_results, 'O2zt', lbl=r'Oxygen, $[mmol / L]$',  cmap=cmocean.cm.oxy)

# %%
contour_plot(MyLake_results, 'Czt', lbl=r'Algae (1-st group), $[mg-P / m^3]$', cmap=cmocean.cm.algae)

# %%
contour_plot(MyLake_results, 'Chlzt', lbl=r'Algae (2-nd group), $[mg-P / m^3]$', cmap=cmocean.cm.algae)

# %%
contour_plot(Sediment_results, 'OMzt', lbl=r'OM1, $[mmol / L]$', cmap=cmocean.cm.algae)

# %%
contour_plot(MyLake_results, 'Pzt', lbl=r'$PO_4$, $[mg-P / m^3]$')

# %%
contour_plot(Sediment_results, 'PO4zt', lbl=r'PO4, $[mmol / L]$')

# %%
contour_plot(MyLake_results, 'PPzt', lbl=r'P sorbed on Fe, $[mg-P / m^3]$')

# %%
contour_plot(Sediment_results, 'PO4adsazt', lbl=r'P sorbed on Fe, $[mmol / L]$')

# %%
contour_plot(MyLake_results, 'Fe3zt', lbl=r'Fe(3+), $[mg / m^3]$')

# %%
contour_plot(Sediment_results, 'FeOH3zt', lbl=r'Fe(3+), $[mmol / L]$')

# %%
contour_plot(MyLake_results, 'Fe2zt', lbl=r'Fe(2+), $[mg / m^3]$')

# %%
contour_plot(Sediment_results, 'Fe2zt', lbl=r'Fe(2+), $[mmol / L]$')

# %%
contour_plot(MyLake_results, 'DOPzt', lbl=r'DOP, $[mg-P / m^3]$', cmap=cmocean.cm.algae)

# %%
contour_plot(Sediment_results, 'DOM1zt', lbl=r'DOP, $[mmol / L]$', cmap=cmocean.cm.algae)

# %%
contour_plot(MyLake_results, 'DOCzt', lbl=r'DOC, $[mg-P / m^3]$', cmap=cmocean.cm.algae)

# %%
contour_plot(Sediment_results, 'DOM2zt', lbl=r'DOC, $[mmol / L]$', cmap=cmocean.cm.algae)

# %%
contour_plot(MyLake_results, 'Szt', lbl=r'Solids, $[mg / m3]$')
