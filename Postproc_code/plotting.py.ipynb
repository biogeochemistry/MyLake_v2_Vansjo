# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as tkr
import matplotlib.dates as mdates
import datetime
from matplotlib.colors import ListedColormap
import seaborn as sns
sns.set_style("whitegrid")
sns.set_style("ticks")
import scipy.io as sio
import cmocean
from ploting import *

# %matplotlib inline

# %%
MyLake_results, Sediment_results = load_data()

# %%
years_ago=1

# %%
plot_fit(MyLake_results)

# %%
contour_plot(MyLake_results, 'Tzt', lbl='T, [C]', years_ago=years_ago, cmap=cmocean.cm.thermal)

# %%
contour_plot(MyLake_results, 'PAR_zt', lbl=r'Solar Irradiance, $[mol / m^2 / s]$', years_ago=years_ago, cmap=cmocean.cm.solar)

# %%
contour_plot(MyLake_results, 'H_sw_zt', lbl=r'Alagae (1-st group) Limiting Light Function, H', years_ago=years_ago, cmap=cmocean.cm.solar)

# %%
contour_plot(MyLake_results, 'H_sw_zt_2', lbl=r'Alagae (2-nd group) Limiting Light Function, H', years_ago=years_ago, cmap=cmocean.cm.solar)

# %%
contour_plot(MyLake_results, 'O2zt', lbl=r'Oxygen, $[mg / m^3]$', years_ago=years_ago, cmap=cmocean.cm.oxy)

# %%
contour_plot(Sediment_results, 'O2zt', lbl=r'Oxygen, $[mmol / L]$', years_ago=years_ago,  cmap=cmocean.cm.oxy)

# %%
contour_plot(MyLake_results, 'Czt', lbl=r'Algae (1-st group), $[mg-P / m^3]$', years_ago=years_ago, cmap=cmocean.cm.algae)

# %%
contour_plot(MyLake_results, 'Chlzt', lbl=r'Algae (2-nd group), $[mg-P / m^3]$', years_ago=years_ago, cmap=cmocean.cm.algae)

# %%
contour_plot(Sediment_results, 'OMzt', lbl=r'OM1, $[mmol / L]$', years_ago=years_ago, cmap=cmocean.cm.algae)

# %%
contour_plot(MyLake_results, 'Pzt', lbl=r'$PO_4$, $[mg-P / m^3]$', years_ago=years_ago)

# %%
contour_plot(Sediment_results, 'PO4zt', lbl=r'PO4, $[mmol / L]$', years_ago=years_ago)

# %%
contour_plot(MyLake_results, 'PPzt', lbl=r'P sorbed on Fe, $[mg-P / m^3]$', years_ago=years_ago)

# %%
contour_plot(Sediment_results, 'PO4adsazt', lbl=r'P sorbed on Fe, $[mmol / L]$', years_ago=years_ago)

# %%
contour_plot(MyLake_results, 'Fe3zt', lbl=r'Fe(3+), $[mg / m^3]$', years_ago=years_ago)

# %%
contour_plot(Sediment_results, 'FeOH3zt', lbl=r'Fe(3+), $[mmol / L]$', years_ago=years_ago)

# %%
contour_plot(MyLake_results, 'Fe2zt', lbl=r'Fe(2+), $[mg / m^3]$', years_ago=years_ago)

# %%
contour_plot(Sediment_results, 'Fe2zt', lbl=r'Fe(2+), $[mmol / L]$', years_ago=years_ago)

# %%
contour_plot(MyLake_results, 'DOPzt', lbl=r'DOP, $[mg-P / m^3]$', cmap=cmocean.cm.algae, years_ago=years_ago)

# %%
contour_plot(Sediment_results, 'DOM1zt', lbl=r'DOP, $[mmol / L]$', cmap=cmocean.cm.algae, years_ago=years_ago)

# %%
contour_plot(MyLake_results, 'DOCzt', lbl=r'DOC, $[mg / m^3]$', cmap=cmocean.cm.algae, years_ago=years_ago)

# %%
contour_plot(Sediment_results, 'DOM2zt', lbl=r'DOC, $[mmol / L]$', cmap=cmocean.cm.algae, years_ago=years_ago)

# %%
contour_plot(MyLake_results, 'Szt', lbl=r'Solids, $[mg / m3]$', years_ago=years_ago)

# %%
contour_plot(MyLake_results, 'NO3zt', lbl=r'NO3, $[mg / m^3]$', years_ago=years_ago)

# %%
contour_plot(Sediment_results, 'NO3zt', lbl=r'NO3, $[mmol / L]$', years_ago=years_ago)

# %%
contour_plot(MyLake_results, 'NH4zt', lbl=r'NH4, $[mg / m^3]$', years_ago=years_ago)

# %%
contour_plot(Sediment_results, 'NH4zt', lbl=r'NH4, $[mmol / L]$', years_ago=years_ago)

# %%
contour_plot(Sediment_results, 'HCO3zt', lbl=r'HCO3, $[mmol / L]$', years_ago=years_ago)

# %%
plot_flux(Sediment_results, 'Ox', lbl=r'Oxygen Flux, $[mg / m^2 / d]$', years_ago=years_ago)

# %%
plot_flux(Sediment_results, 'PO4', lbl=r'$PO_4$ Flux, $[mg / m^2 / d]$', years_ago=years_ago)

# %%
plot_flux(Sediment_results, 'PO4', lbl=r'Oxygen Flux, $[mg / m^2 / d]$', years_ago=years_ago)

# %%
plot_flux(Sediment_results, 'NH4', lbl=r'$NH_4^+$ Flux, $[mg / m^2 / d]$', years_ago=years_ago)

# %%
plot_flux(Sediment_results, 'NO3', lbl=r'$NO_3^-$ Flux, $[mg / m^2 / d]$', years_ago=years_ago)

# %%
contour_plot(MyLake_results, 'Kzt', lbl=r'Vertical diffusion coefficient $[m^2 d^{-1}]$', years_ago=years_ago, cmap=cmocean.cm.haline)
