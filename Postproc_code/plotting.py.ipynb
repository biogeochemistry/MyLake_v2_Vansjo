# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as tkr
import matplotlib.dates as mdates
import datetime
from matplotlib.colors import ListedColormap
import seaborn as sns
sns.set_style("whitegrid")
sns.set_style("ticks")
import scipy.io as sio
import cmocean
from ploting import *

# %matplotlib inline

from datetime import datetime
str(datetime.now())
# Out:
# '2017-04-27 11:20:59.662201'

# %%
years_ago=1

# %%
MyLake_results, Sediment_results = load_data()

# %%
plot_fit(MyLake_results)

# %%
contour_plot(MyLake_results, ['O2zt'], lbl=r'Oxygen, $[mg / m^3]$', years_ago=years_ago, cmap=cmocean.cm.oxy)

# %%
contour_plot(Sediment_results, ['O2zt'], lbl=r'Oxygen, $[mmol / L]$', years_ago=years_ago, cmap=cmocean.cm.oxy)

# %%
contour_plot(MyLake_results, ['Fe3zt'], lbl=r'Fe3, $[mg / m^3]$', years_ago=years_ago)

# %%
contour_plot(MyLake_results, ['Chlzt'], lbl=r'Chlz, $[mg / m^3]$', years_ago=years_ago, cmap=cmocean.cm.algae)

# %%
contour_plot(MyLake_results, ['Czt'], lbl=r'Cz, $[mg / m^3]$', years_ago=years_ago, cmap=cmocean.cm.algae)

# %%
plot_profile(Sediment_results, ['FeOH3zt', 'Fe2zt'], '[$mmol/L$] or [$mmol/g$]')

# %%
plot_profile(Sediment_results, ['NO3zt','O2zt', 'SO4zt', 'Fe2zt'])

# %%
plot_profile(Sediment_results, ['PO4zt', 'PO4adsazt'])

# %%
plot_profile(Sediment_results, ['SO4zt', 'HSzt'])

# %%
plot_profile(Sediment_results, ['OMbzt', 'OMzt', 'DOM2zt'])

# %%
contour_plot(MyLake_results, ['DOPzt', 'Chlzt', 'Czt', 'Pzt', 'PPzt'], lbl=r'Total P, $[mg / m^3]$', years_ago=years_ago)

# %%
plot_flux(Sediment_results, 'OM2', lbl='OM2-P flux')

# %%
plot_flux(Sediment_results, 'OM1', lbl='OM1-P flux')

# %%
plot_flux(Sediment_results, 'Fe2', lbl='Fe2 flux [$mg / m^2 / d$]')

# %%
plot_flux(Sediment_results, 'NO3', lbl='NO3 flux')

# %%
plot_flux(Sediment_results, 'FeOH3', lbl='FeOH3 flux, mg/m2/d ')

# %%
contour_plot(MyLake_results, ['POCzt'], lbl=r'POCzt, $[mg / m^3]$', years_ago=years_ago)

# %%
contour_plot(MyLake_results, ['PPzt'], lbl=r'PPzt, $[mg / m^3]$', years_ago=years_ago)

# %%
contour_plot(MyLake_results, ['H_sw_zt'], lbl=r'H1, $[mg / m^3]$', years_ago=years_ago, cmap=cmocean.cm.solar)

# %%
contour_plot(MyLake_results, ['H_sw_zt_2'], lbl=r'H2, $[mg / m^3]$', years_ago=years_ago, cmap=cmocean.cm.solar)

# %%
contour_plot(Sediment_results, ['DOM1zt'], lbl=r'DOC, $[mmol / L]$', years_ago=years_ago)

# %%
plot_profile(Sediment_results, ['PO4adsazt'])

# %%
plot_flux(Sediment_results, 'PO4', lbl='PO4 flux')

# %%
plot_flux(Sediment_results, 'Ox', lbl='Ox flux')

# %%
contour_plot(MyLake_results, ['Tzt'], lbl=r'Tz, $[mg / m^3]$', years_ago=years_ago, cmap=cmocean.cm.thermal)

# %%
contour_plot(MyLake_results, ['NH4zt'], lbl=r'NH4, $[mg / m^3]$', years_ago=years_ago)

# %%
contour_plot(MyLake_results, ['NO3zt'], lbl=r'NO3, $[mg / m^3]$', years_ago=years_ago)
