# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as tkr
import matplotlib.dates as mdates
import datetime
from matplotlib.colors import ListedColormap
import seaborn as sns
sns.set_style("whitegrid")
sns.set_style("ticks")
import scipy.io as sio
import cmocean
from ploting import *

# %matplotlib inline

# %%
MyLake_results, Sediment_results = load_data()

# %%
plot_fit(MyLake_results)

# %%
contour_plot(MyLake_results, 'Tzt', lbl='T, [C]', cmap=cmocean.cm.thermal)

# %%
contour_plot(MyLake_results, 'O2zt', lbl='Oxygen, [mg / m3]', cmap=cmocean.cm.oxy)

# %%
contour_plot(Sediment_results, 'O2zt', lbl='Oxygen, [mmol / L]',  cmap=cmocean.cm.oxy)

# %%
contour_plot(MyLake_results, 'Czt', lbl='Algae (1-st group), [mg / m3]', cmap=cmocean.cm.algae)

# %%
contour_plot(MyLake_results, 'Chlzt', lbl='Algae (2-nd group), [mg / m3]', cmap=cmocean.cm.algae)

# %%
contour_plot(Sediment_results, 'OMzt', lbl='OM1, [mmol / L]', cmap=cmocean.cm.algae)

# %%
contour_plot(MyLake_results, 'Pzt', lbl='PO4, [mg / m3]')

# %%
contour_plot(Sediment_results, 'PO4zt', lbl='PO4, [mmol / L]')

# %%
contour_plot(MyLake_results, 'PPzt', lbl='P sorbed on Fe, [mg / m3]')

# %%
contour_plot(Sediment_results, 'PO4adsazt', lbl='P sorbed on Fe, [mmol / L]')

# %%
contour_plot(MyLake_results, 'Fe3zt', lbl='Fe(3+), [mg / m3]')

# %%
contour_plot(Sediment_results, 'FeOH3zt', lbl='Fe(3+), [mmol / L]')
