# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as tkr
import matplotlib.dates as mdates
import datetime
from matplotlib.colors import ListedColormap
import seaborn as sns
sns.set_style("whitegrid")
sns.set_style("ticks")
import scipy.io as sio
import cmocean
from ploting import *



# %matplotlib inline

from datetime import datetime
str(datetime.now())
# Out:
# '2017-08-02 15:44:27.950477'

# %%
from ploting import *
plotter = ResultsPlotter(years_ago=0.0)

# %%
plotter.phosphorus_fit()

# %%
plotter.temperature_fit()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-301-d3ba10d40b63> in <module>()
# ----> 1 plotter.temperature_fit()
#
# /Users/MarkelovIgor/git/biogeochemistry/MyLake_v2_Vansjo/Postproc_code/ploting.py in temperature_fit(self)
#     337
#     338     def temperature_fit(self):
# --> 339         results = self.env_getter('water-column', basin=2)
#     340         T = results['T'][0, 0]
#     341         t = results['days'][0, 0][0] - 366
#
# /Users/MarkelovIgor/git/biogeochemistry/MyLake_v2_Vansjo/Postproc_code/ploting.py in env_getter(self, env, basin)
#      71             results = self.sediment_results['basin' + str(basin)][0, 0]
#      72         elif env == 'water-column':
# ---> 73             results = self.myLake_results['basin' + str(basin)][0, 0]
#      74         return results
#      75
#
# ValueError: no field of name basin2
