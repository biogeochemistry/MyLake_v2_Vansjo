# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as tkr
import matplotlib.dates as mdates
import datetime
from matplotlib.colors import ListedColormap
import seaborn as sns
sns.set_style("whitegrid")
sns.set_style("ticks")
import scipy.io as sio
import cmocean
from ploting import *

# %matplotlib inline

from datetime import datetime
str(datetime.now())
# Out:
# '2017-05-12 12:01:45.522086'

# %%
from ploting import *
plotter = ResultsPlotter(years_ago=0.0)

# %%
plotter.plot_flux('FeOH3', convert_units=True)

# %%
plotter.plot_rate_profile('sediment', ['FeOH3zt'])

# %%
plotter.plot_rate_profile('sediment', ['Fe2zt'])

# %%
plotter.plot_flux('Fe2', convert_units=True)

# %%
plotter.plot_rate_profile('water-column', ['Fe3zt'])

# %%
plotter.plot_rate_profile('water-column', ['Fe2zt'])

# %%
plotter.plot_profile('sediment', ['Fe2zt'], convert_units=False)

# %%
plotter.plot_profile('sediment', ['Fe2zt', 'FeSzt', 'FeS2zt'], convert_units=False)

# %%
plotter.plot_flux('Fe2', convert_units=True)

# %%
plotter.contour_plot('water-column', ['Fe3zt'])

# %%
plotter.bulk_sediment_profile(['NO3zt','02zt'])

# %%
plotter.plot_profile('sediment', ['OMbzt'])

# %%
plotter.plot_profile('water-column', ['Fe3zt'])

# %%
plotter.plot_profile('water-column', ['Fe3zt'])
